# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data23= pd.read_csv('gastos_costos_23.csv')

# %%
#Conocer estructura y eliminar columnas si es necesario
data23 = data23.drop(['Unnamed: 0'], axis=1)
data23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        397 non-null    object
#  1   Folio        397 non-null    object
#  2   UUID         397 non-null    object
#  3   RFC          397 non-null    object
#  4   Proveedor    397 non-null    object
#  5   TIPO GASTO   397 non-null    object
#  6   Descripción  397 non-null    object
#  7   MP           397 non-null    object
#  8   FP           397 non-null    float64
#  9   TC           397 non-null    float64
#  10  Importe      397 non-null    float64
#  11  IVA          397 non-null    float64
#  12  RET ISR      397 non-null    float64
#  13  RET IVA      397 non-null    float64
#  14  Otros        397 non-null    int64
#  15  TOTAL MX     397 non-null    float64
#  16  TOTAL SAT    397 non-null    float64
#  17  Tipo         397 non-null    object
# ...

# %%
#Filtrar por cuantitativas (Atipicos)
cuantitativas = data23.iloc[:,8:16]
cuantitativas
# Out:
#        FP   TC   Importe      IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0    44.0  1.0      0.00     0.00      0.0      0.0      0      0.00
# 1    44.0  1.0      0.00     0.00      0.0      0.0      0      0.00
# 2    99.0  1.0   5551.38   888.22      0.0      0.0      0   6439.60
# 3    99.0  1.0   5551.98   888.32      0.0      0.0      0   6440.30
# 4    99.0  1.0   8454.37  1352.70      0.0      0.0      0   9807.07
# ..    ...  ...       ...      ...      ...      ...    ...       ...
# 392   3.0  1.0      0.00     0.00      0.0      0.0      0      0.00
# 393   1.0  1.0    220.00     0.00      0.0      0.0      0    220.00
# 394   3.0  1.0  18071.52   682.40      0.0      0.0      0  18753.92
# 395   5.0  1.0  14472.32     0.00      0.0      0.0      0  14472.32
# 396  44.0  1.0      0.00     0.00      0.0      0.0      0      0.00
#
# [397 rows x 8 columns]

# %%
#Filtrar por cualitativas
cualitativas=data23.iloc[:,[0,1,2,3,4,5,6,7,17,18,19]]
cualitativas
# Out:
#           Fecha       Folio                                  UUID  \
# 0    2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1    2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2    2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3    2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4    2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..          ...         ...                                   ...
# 392  2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393  2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394  2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395  2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396  2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data23.isnull().sum()
valores_nulos
# Out:
# Fecha          0
# Folio          0
# UUID           0
# RFC            0
# Proveedor      0
# TIPO GASTO     0
# Descripción    0
# MP             0
# FP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# Otros          0
# TOTAL MX       0
# TOTAL SAT      0
# Tipo           0
# Status         0
# Poliza         0
# dtype: int64

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido FP            243.00
# TC              1.00
# Importe      9075.43
# IVA          1120.00
# RET ISR         0.00
# RET IVA         0.00
# Otros           0.00
# TOTAL MX    10527.50
# dtype: float64
# Limite inferior permitido FP          -141.00
# TC             1.00
# Importe    -5259.05
# IVA         -672.00
# RET ISR        0.00
# RET IVA        0.00
# Otros          0.00
# TOTAL MX   -6100.50
# dtype: float64

# %%
#Obtenemos datos limpios del Dataframe
data2023= cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data2023
# Out:
#        FP   TC  Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0    44.0  1.0     0.00    0.00      0.0      0.0      0      0.00
# 1    44.0  1.0     0.00    0.00      0.0      0.0      0      0.00
# 2    99.0  1.0  5551.38  888.22      0.0      0.0      0   6439.60
# 3    99.0  1.0  5551.98  888.32      0.0      0.0      0   6440.30
# 4    99.0  1.0  8454.37     NaN      0.0      0.0      0   9807.07
# ..    ...  ...      ...     ...      ...      ...    ...       ...
# 392   3.0  1.0     0.00    0.00      0.0      0.0      0      0.00
# 393   1.0  1.0   220.00    0.00      0.0      0.0      0    220.00
# 394   3.0  1.0      NaN  682.40      0.0      0.0      0       NaN
# 395   5.0  1.0      NaN    0.00      0.0      0.0      0       NaN
# 396  44.0  1.0     0.00    0.00      0.0      0.0      0      0.00
#
# [397 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2023.isnull().sum()
valores_nulos
# Out:
# FP           0
# TC           2
# Importe     50
# IVA         49
# RET ISR      9
# RET IVA      9
# Otros        0
# TOTAL MX    46
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data2023.copy()
data_clean=data_clean.fillna(round(data2023.mean(),1))
data_clean
# Out:
#        FP   TC  Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0    44.0  1.0     0.00    0.00      0.0      0.0      0      0.00
# 1    44.0  1.0     0.00    0.00      0.0      0.0      0      0.00
# 2    99.0  1.0  5551.38  888.22      0.0      0.0      0   6439.60
# 3    99.0  1.0  5551.98  888.32      0.0      0.0      0   6440.30
# 4    99.0  1.0  8454.37  176.80      0.0      0.0      0   9807.07
# ..    ...  ...      ...     ...      ...      ...    ...       ...
# 392   3.0  1.0     0.00    0.00      0.0      0.0      0      0.00
# 393   1.0  1.0   220.00    0.00      0.0      0.0      0    220.00
# 394   3.0  1.0  1521.50  682.40      0.0      0.0      0   1845.00
# 395   5.0  1.0  1521.50    0.00      0.0      0.0      0   1845.00
# 396  44.0  1.0     0.00    0.00      0.0      0.0      0      0.00
#
# [397 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# FP          0
# TC          0
# Importe     0
# IVA         0
# RET ISR     0
# RET IVA     0
# Otros       0
# TOTAL MX    0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe original
fig = plt.figure(figsize =(15, 8))
data23.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe limpio
fig = plt.figure(figsize =(15, 8))
data_clean.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Unimos las columnas cualitativas con el dataframe
Datos_limpios = pd.concat([cualitativas, data_clean], axis=1)
Datos_limpios
# Out:
#           Fecha       Folio                                  UUID  \
# 0    2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1    2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2    2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3    2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4    2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..          ...         ...                                   ...
# 392  2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393  2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394  2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395  2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396  2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# ...

# %%
#Convertir archivo filtrado a CSV
Datos_limpios.to_csv("Valores Atípicos (Gastos y costos 2023).csv")

# %%
#Descargar archivo en csv
from google.colab import files
files.download("Valores Atípicos (Gastos y costos 2023).csv")
